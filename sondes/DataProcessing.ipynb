# %% [markdown]
# # GRAW Radiosondes Processed Data. King George Island. TARP-02

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
data0  = np.genfromtxt('Flight1_ProfileData.txt',skip_header=1)
data1  = np.genfromtxt('Flight2_ProfileData.txt',skip_header=1)
data2  = np.genfromtxt('Flight3_ProfileData.txt',skip_header=1)
data2r = np.genfromtxt('Flight3_RawData.txt',skip_header=12)
data3  = np.genfromtxt('Flight4_ProfileData.txt',skip_header=1)
data4  = np.genfromtxt('Flight5_ProfileData.txt',skip_header=1)
#data5  = np.genfromtxt('Flight6_ProfileData.txt',skip_header=1)
data6  = np.genfromtxt('Flight7_ProfileData.txt',skip_header=1)

# %% [markdown]
# ## Santiago First Flight in DMC

# %% [markdown]
# Make plots of:
#
# - Temperature and Humidity together (Going up).
# - Temperature profile (Going up).
# - Humidity profile (Going up).
# - Windspeed profile (Full).
# - Wind direction (Check the plot in internet) (Full).
# - Map tracking (Check how to load the map from internet).

# %%
alt0  = data0[:,6]*0.001
temp0 = data0[:,2]
hum0  = data0[:,3]
pres0 = data0[:,1]
lon0  = data0[:,8]
lat0  = data0[:,9]

ws0   = data0[:,4]
wd0   = data0[:,5]

np.where(alt0 == alt0.max())
# Out:
# (array([2289], dtype=int64),)

# %%
altgu0  = alt0[:2289]
altgd0  = alt0[2289:]

tempgu0 = temp0[:2289]
humgu0  = hum0[:2289]

presgu0 = pres0[:2289]
presgd0 = pres0[2289:]
wsgu0   = ws0[:2289]
wsgd0   = ws0[2289:]

plt.figure()
plt.plot(tempgu0,altgu0,label='Temperature')
plt.ylim((0,20))
plt.xlim((-80,20))
plt.grid('on')
plt.title('Atmospheric Profile. Santiago',fontsize=17)
plt.xlabel('Temperature [°C]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.text(-20,13,'Jan 6 2017 1330 UT',fontsize=14)
plt.text(-18,12,'DMC',fontsize=15)
plt.text(-11,12,'Santiago',fontsize=14)

plt.figure()
plt.plot(humgu0,altgu0,label='Relative Humidity')
plt.ylim((0,20))
plt.xlim((0,100))
plt.grid('on')
plt.title('Atmospheric Profile. Santiago',fontsize=17)
plt.xlabel('Relative Humidity [%]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.text(60,13,'Jan 6 2017 1330 UT',fontsize=14)
plt.text(61,12,'DMC',fontsize=15)
plt.text(70,12,'Santiago',fontsize=14)

plt.figure()
plt.plot(tempgu0,altgu0,label='Temperature')
plt.plot(humgu0,altgu0,label='Relative Humidity')
plt.ylim((0,20))
plt.xlim((-80,100))
plt.grid('on')
plt.title('Atmospheric Profile. Santiago',fontsize=17)
plt.xlabel('   Temperature [°C]             Relative Humidity [%]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(40,13,'Jan 6 2017 1330 UT',fontsize=14)
plt.text(41,12,'DMC',fontsize=15)
plt.text(58,12,'Santiago',fontsize=14)

plt.figure()
plt.plot(wsgu0,altgu0,label='Windspeed Going up')
plt.plot(wsgd0,altgd0,label='Windspeed Going down')
plt.ylim((0,20))
plt.xlim((0,30))
plt.grid('on')
plt.title('Atmospheric Profile. Santiago',fontsize=17)
plt.xlabel('Windspeed [m/s]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(2,17,'Jan 6 2017 1330 UT',fontsize=14)
plt.text(2.1,16,'DMC',fontsize=15)
plt.text(2.8,16,'Santiago',fontsize=14)

plt.figure()
plt.plot(presgu0,altgu0,label='Windspeed Going up')
plt.plot(presgd0,altgd0,label='Windspeed Going down')
plt.ylim((0,20))
plt.xlim((0,1000))
plt.grid('on')
plt.title('Atmospheric Profile. Santiago',fontsize=17)
plt.xlabel('Windspeed [m/s]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(630,13,'Jan 6 2017 1330 UT',fontsize=14)
plt.text(640,12,'DMC',fontsize=15)
plt.text(790,12,'Santiago',fontsize=14)
# Out:
# C:\Users\Edgardo\Anaconda3\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Antarctica Launch 1

# %% [markdown]
# Make plots of:
#
# - Temperature profile (Going up).
# - Humidity profile (Going up).
# - Pressure profile (Going up).
# - Map tracking (Check how to load the map from internet).
#
#
# - Windspeed profile (Full).
# - Wind direction (Check the plot in internet) (Full).
# - Temperature and Humidity together (Going up).

# %%
alt1  = data1[:,6]*0.001
temp1 = data1[:,2]
hum1  = data1[:,3]
pres1 = data1[:,1]
lon1  = data1[:,8]
lat1  = data1[:,9]

ws1   = data1[:,4]
wd1   = data1[:,5]

np.where(alt1 == alt1.max())
# Out:
# (array([1945], dtype=int64),)

# %%
altgu1  = alt1[:1945]
altgd1  = alt1[1945:]

tempgu1 = temp1[:1945]
humgu1  = hum1[:1945]

presgu1 = pres1[:1945]
presgd1 = pres1[1945:]
wsgu1   = ws1[:1945]
wsgd1   = ws1[1945:]

plt.figure()
plt.plot(tempgu1,altgu1,label='Temperature')
plt.ylim((0,20))
plt.xlim((-70,10))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Temperature [°C]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.text(-20,13,'Jan 12 2017 1205 UT',fontsize=14)
plt.text(-20,12,'TARP-02',fontsize=15)
plt.text(-8,12,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(humgu1,altgu1,label='Relative Humidity')
plt.ylim((0,20))
plt.xlim((0,100))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Relative Humidity [%]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.text(60,13,'Jan 12 2017 1205 UT',fontsize=14)
plt.text(61,12,'TARP-02',fontsize=15)
plt.text(76.5,12,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(tempgu1,altgu1,label='Temperature')
plt.plot(humgu1,altgu1,label='Relative Humidity')
plt.ylim((0,20))
plt.xlim((-70,100))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Temperature [°C]                 Relative Humidity [%]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(40,13,'Jan 12 2017 1205 UT',fontsize=14)
plt.text(41,12,'TARP-02',fontsize=15)
plt.text(66,12,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(wsgu1,altgu1,label='Windspeed Going up')
plt.plot(wsgd1,altgd1,label='Windspeed Going down')
plt.ylim((0,20))
plt.xlim((0,15))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Windspeed [m/s]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(9.8,13,'Jan 12 2017 1205 UT',fontsize=14)
plt.text(9.9,12,'TARP-02',fontsize=15)
plt.text(12.1,12,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(presgu1,altgu1,label='Pressure Going Up')
plt.plot(presgd1,altgd1,label='Pressure Going Down')
plt.ylim((0,20))
plt.xlim((0,1000))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Pressure [hPa]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.text(630,13,'Jan 12 2017 1205 UT',fontsize=14)
plt.text(640,12,'TARP-02',fontsize=15)
plt.text(790,12,'Fildes Bay',fontsize=14)
# Out:
# <img src="data:image/png;base64,...">
# C:\Users\Edgardo\Anaconda3\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Antarctica Launch 2

# %% [markdown]
# Make plots of:
#
# - Temperature profile (Going up).
# - Humidity profile (Going up).
# - Pressure profile (Going up).
#
#
# - Temperature and Humidity together (Going up).

# %%
temp2r = data2r[:,2]
hum2r  = data2r[:,3]
pres2r = data2r[:,1]

sorted(pres2r)
np.where(pres2r == 194.81)
# Out:
# (array([2298], dtype=int64),)

# %%
presgu2r = pres2r[:2298]
tempgu2r = temp2r[:2298]
humgu2r  = hum2r[:2298]

# %%
plt.figure()
plt.plot(temp2r,pres2r,label='Temperature')
plt.ylim((1000,0))
plt.xlim((-80,10))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Temperature [°C]',fontsize=14)
plt.ylabel('Pressure [hPa]',fontsize=14)
plt.text(-20,13,'Jan 13 2017 11? UT',fontsize=14)
plt.text(-20,12,'TARP-02',fontsize=15)
plt.text(-8,12,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(hum2r,pres2r,label='Relative Humidity')
plt.ylim((1000,0))
plt.xlim((0,100))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Relative Humidity [%]',fontsize=14)
plt.ylabel('Pressure [hPa]',fontsize=14)
plt.text(60,13,'Jan 13 2017 11? UT',fontsize=14)
plt.text(61,12,'TARP-02',fontsize=15)
plt.text(76.5,12,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(temp2r,pres2r,label='Temperature')
plt.plot(hum2r,pres2r,label='Relative Humidity')
plt.ylim((1000,0))
plt.xlim((-70,100))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Temperature [°C]                 Relative Humidity [%]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(40,13,'Jan 13 2017 11? UT',fontsize=14)
plt.text(41,12,'TARP-02',fontsize=15)
plt.text(66,12,'Fildes Bay',fontsize=14)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
pres2r.tolist()

for i in range(len(pres2r)):
    if pres2r[i] == 0 or math.isnan(pres2r[i]) == True:
        del pres2r[i]
        del temp2r[i]
        del hum2r[i]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-a440c3d6cd21> in <module>()
#       3 for i in range(len(pres2r)):
#       4     if pres2r[i] == 0 or math.isnan(pres2r[i]) == True:
# ----> 5         del pres2r[i]
#       6         del temp2r[i]
#       7         del hum2r[i]
#
# ValueError: cannot delete array elements

# %% [markdown]
# ## Antarctica Launch 3

# %% [markdown]
# Make plots of:
#
# - Temperature profile (Going up).
# - Humidity profile (Going up).
# - Pressure profile (Going up).
# - Map tracking (Check how to load the map from internet).
#
#
# - Windspeed profile (Full).
# - Wind direction (Check the plot in internet) (Full).
# - Temperature and Humidity together (Going up).

# %%
alt3  = data3[:,6]*0.001
temp3 = data3[:,2]
hum3  = data3[:,3]
pres3 = data3[:,1]
lon3  = data3[:,8]
lat3  = data3[:,9]

ws3   = data3[:,4]
wd3   = data3[:,5]

np.where(alt3 == alt3.max())
# Out:
# (array([2232], dtype=int64),)

# %%
2232/2
# Out:
# 1116.0

# %%
altgu3  = alt3[:2232]
altgd3  = alt3[2232:]
althum  = alt3[:960]

tempgu3 = temp3[:2232]
humgu3  = hum3[:2232]
humgu3n = hum3[:960]

presgu3 = pres3[:2232]
presgd3 = pres3[2232:]
wsgu3   = ws3[:2232]
wsgd3   = ws3[2232:]

plt.figure()
plt.plot(tempgu3,altgu3,label='Temperature')
plt.ylim((0,20))
plt.xlim((-70,10))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Temperature [°C]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.text(-20,13,'Jan 14 2017 1117 UT',fontsize=14)
plt.text(-20,12,'TARP-02',fontsize=15)
plt.text(-8,12,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(humgu3n,althum,label='Relative Humidity')
plt.ylim((0,20))
plt.xlim((0,100))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Relative Humidity [%]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.text(60,13,'Jan 14 2017 1117 UT',fontsize=14)
plt.text(61,12,'TARP-02',fontsize=15)
plt.text(76.5,12,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(tempgu3,altgu3,label='Temperature')
plt.plot(humgu3,altgu3,label='Relative Humidity')
plt.ylim((0,20))
plt.xlim((-70,100))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Temperature [°C]                 Relative Humidity [%]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(40,13,'Jan 14 2017 1117 UT',fontsize=14)
plt.text(41,12,'TARP-02',fontsize=15)
plt.text(66,12,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(wsgu3,altgu3,label='Windspeed Going up')
plt.plot(wsgd3,altgd3,label='Windspeed Going down')
plt.ylim((0,20))
plt.xlim((0,15))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Windspeed [m/s]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(9.8,13,'Jan 14 2017 1117 UT',fontsize=14)
plt.text(9.9,12,'TARP-02',fontsize=15)
plt.text(12.1,12,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(presgu3,altgu3,label='Pressure Going up')
plt.plot(presgd3,altgd3,label='Pressure Going down')
plt.ylim((0,20))
plt.xlim((0,1000))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Pressure [hPa]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(630,13,'Jan 14 2017 1117 UT',fontsize=14)
plt.text(640,12,'TARP-02',fontsize=15)
plt.text(790,12,'Fildes Bay',fontsize=14)
# Out:
# <img src="data:image/png;base64,...">
# C:\Users\Edgardo\Anaconda3\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Antarctica Launch 4

# %% [markdown]
# Make plots of:
#
# - Temperature profile (Going up).
# - Humidity profile (Going up).
# - Pressure profile (Going up).
# - Map tracking (Check how to load the map from internet).
#
#
# - Windspeed profile (Full).
# - Wind direction (Check the plot in internet) (Full).
# - Temperature and Humidity together (Going up).

# %%
alt4  = data4[:,6]*0.001
temp4 = data4[:,2]
hum4  = data4[:,3]
pres4 = data4[:,1]
lon4  = data4[:,8]
lat4  = data4[:,9]

ws4   = data4[:,4]
wd4   = data4[:,5]

np.where(alt4 == alt4.max())
# Out:
# (array([660], dtype=int64),)

# %%
altgu4  = alt4[:660]
altgd4  = alt4[660:]

tempgu4 = temp4[:660]
humgu4  = hum4[:660]

presgu4 = pres4[:660]
presgd4 = pres4[660:]
wsgu4   = ws4[:660]
wsgd4   = ws4[660:]

plt.figure()
plt.plot(tempgu4,altgu4,label='Temperature')
plt.ylim((0,8))
plt.xlim((-70,10))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Temperature [°C]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.text(-20,6,'Jan 15 2017 1113 UT',fontsize=14)
plt.text(-20,5.5,'TARP-02',fontsize=15)
plt.text(-8,5.5,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(humgu4,altgu4,label='Relative Humidity')
plt.ylim((0,8))
plt.xlim((0,100))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Relative Humidity [%]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.text(60,6,'Jan 15 2017 1113 UT',fontsize=14)
plt.text(60.5,5.5,'TARP-02',fontsize=15)
plt.text(76,5.5,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(tempgu4,altgu4,label='Temperature')
plt.plot(humgu4,altgu4,label='Relative Humidity')
plt.ylim((0,8))
plt.xlim((-70,100))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Temperature [°C]                 Relative Humidity [%]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='lower left',fontsize=12)
plt.text(-30,7,'Jan 15 2017 1113 UT',fontsize=14)
plt.text(-29,6.5,'TARP-02',fontsize=15)
plt.text(-3.5,6.5,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(wsgu4,altgu4,label='Windspeed Going up')
plt.plot(wsgd4,altgd4,label='Windspeed Going down')
plt.ylim((0,8))
plt.xlim((0,25))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Windspeed [m/s]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='lower right',fontsize=12)
plt.text(5,7,'Jan 15 2017 1113 UT',fontsize=14)
plt.text(5.1,6.5,'TARP-02',fontsize=15)
plt.text(8.8,6.5,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(presgu4,altgu4,label='Pressure Going up')
plt.plot(presgd4,altgd4,label='Pressure Going down')
plt.ylim((0,8))
plt.xlim((0,1000))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Pressure [hPa]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(600,5.8,'Jan 15 2017 1113 UT',fontsize=14)
plt.text(600,5.3,'TARP-02',fontsize=15)
plt.text(750,5.3,'Fildes Bay',fontsize=14)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Antarctica Launch 6

# %% [markdown]
# Make plots of:
#
# - Temperature profile (Going up).
# - Humidity profile (Going up).
# - Pressure profile (Going up).
# - Map tracking (Check how to load the map from internet).
#
#
# - Windspeed profile (Full).
# - Wind direction (Check the plot in internet) (Full).
# - Temperature and Humidity together (Going up).

# %%
alt6  = data6[:,6]*0.001
temp6 = data6[:,2]
hum6  = data6[:,3]
pres6 = data6[:,1]
lon6  = data6[:,8]
lat6  = data6[:,9]

ws6   = data6[:,4]
wd6   = data6[:,5]

np.where(alt6 == alt6.max())
# Out:
# (array([677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687, 688, 689,
#         690, 691, 692, 693, 694, 695, 696, 697, 698, 699, 700, 701, 702,
#         703, 704, 705, 706, 707, 708, 709, 710, 711, 712, 713, 714, 715,
#         728, 729, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 740,
#         741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753,
#         754, 755, 756, 757, 758, 759, 760, 761], dtype=int64),)

# %%
altgu6  = alt6[:761]
altgd6  = alt6[761:]

tempgu6 = temp6[:761]
humgu6  = hum6[:761]

presgu6 = pres6[:761]
presgd6 = pres6[761:]
wsgu6   = ws6[:761]
wsgd6   = ws6[761:]

plt.figure()
plt.plot(tempgu6,altgu6,label='Temperature')
plt.ylim((0,20))
plt.xlim((-70,10))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Temperature [°C]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.text(-20,6,'Jan 17 2017 1057 UT',fontsize=14)
plt.text(-20,5.5,'TARP-02',fontsize=15)
plt.text(-8,5.5,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(humgu6,altgu6,label='Relative Humidity')
plt.ylim((0,10))
plt.xlim((0,100))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Relative Humidity [%]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.text(60,6,'Jan 17 2017 1057 UT',fontsize=14)
plt.text(60.5,5.5,'TARP-02',fontsize=15)
plt.text(76,5.5,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(tempgu6,altgu6,label='Temperature')
plt.plot(humgu6,altgu6,label='Relative Humidity')
plt.ylim((0,10))
plt.xlim((-70,100))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Temperature [°C]                 Relative Humidity [%]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='lower left',fontsize=12)
plt.text(-30,7,'Jan 17 2017 1057 UT',fontsize=14)
plt.text(-29,6.5,'TARP-02',fontsize=15)
plt.text(-3.5,6.5,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(wsgu6,altgu6,label='Windspeed Going up')
plt.plot(wsgd6,altgd6,label='Windspeed Going down')
plt.ylim((0,10))
plt.xlim((0,25))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Windspeed [m/s]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='lower right',fontsize=12)
plt.text(5,7,'Jan 17 2017 1057 UT',fontsize=14)
plt.text(5.1,6.5,'TARP-02',fontsize=15)
plt.text(8.8,6.5,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(presgu6,altgu6,label='Pressure Going up')
plt.plot(presgd6,altgd6,label='Pressure Going down')
plt.ylim((0,10))
plt.xlim((0,1000))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Pressure [hPa]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(600,5.8,'Jan 17 2017 1057 UT',fontsize=14)
plt.text(600,5.3,'TARP-02',fontsize=15)
plt.text(750,5.3,'Fildes Bay',fontsize=14)
# Out:
# <img src="data:image/png;base64,...">
# C:\Users\Edgardo\Anaconda3\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Days Comparison

# %%
plt.figure()
plt.plot(tempgu1,altgu1,label='Jan 12 2017 1205 UT')
plt.plot(tempgu3,altgu3,label='Jan 14 2017 1117 UT')
plt.plot(tempgu4,altgu4,label='Jan 15 2017 1107 UT')
plt.ylim((0,20))
plt.xlim((-70,10))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Temperature [°C]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(-18,13,'TARP-02',fontsize=15)
plt.text(-6,13,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(humgu1,altgu1,label='Jan 12 2017 1205 UT')
plt.plot(humgu3n,althum,label='Jan 14 2017 1117 UT')
plt.plot(humgu4,altgu4,label='Jan 15 2017 1107 UT')
plt.ylim((0,20))
plt.xlim((0,100))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Relative Humidity [%]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(65,13,'TARP-02',fontsize=15)
plt.text(80,13,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(wsgu1,altgu1,label='Jan 12 2017 1205 UT')
plt.plot(wsgu3,altgu3,label='Jan 14 2017 1117 UT')
plt.plot(wsgu4,altgu4,label='Jan 15 2017 1107 UT')
plt.ylim((0,20))
plt.xlim((0,25))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Windspeed [m/s]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(16,13,'TARP-02',fontsize=15)
plt.text(19.8,13,'Fildes Bay',fontsize=14)

plt.figure()
plt.plot(presgu1,altgu1,label='Jan 12 2017 1205 UT')
plt.plot(presgu3,altgu3,label='Jan 14 2017 1117 UT')
plt.plot(presgu4,altgu4,label='Jan 15 2017 1107 UT')
plt.ylim((0,20))
plt.xlim((0,1000))
plt.grid('on')
plt.title('Atmospheric Profile. King George Island, Antarctica',fontsize=17)
plt.xlabel('Pressure [hPa]',fontsize=14)
plt.ylabel('Height [km]',fontsize=14)
plt.legend(loc='upper right',fontsize=12)
plt.text(630,13,'TARP-02',fontsize=15)
plt.text(780,13,'Fildes Bay',fontsize=14)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Trackings Maps

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-54-8228cbcad58b> in <module>()
# ----> 1 from mpl_toolkits.basemap import Basemap
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#
# ImportError: No module named 'mpl_toolkits.basemap'
