# %%
import matplotlib.pyplot as plt
import numpy as np
% matplotlib notebook

# %%
filename = "supercooled_water_optical_constants/Hybrid_Linearinterp/240K_Hybrid/Water_Hybrid_240K.txt"
data = np.loadtxt(filename,comments = '%')

# %%
nu = data[:,0]
realPart = data[:,1]
imgPart = data[:,2]
plt.figure()
plt.plot(nu,realPart)
plt.xlim([400,1300])
plt.figure()
plt.plot(nu,imgPart)
plt.xlim([400,1300])
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# (400, 1300)
